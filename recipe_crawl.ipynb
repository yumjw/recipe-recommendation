# %%
import requests
from bs4 import BeautifulSoup
import time
import urllib.request
import re     

import pandas as pd
import numpy as np

# %%
# #---------------------- 크롤링 구간 ----------------------
# url_list = 'https://www.youtube.com/channel/'+creator_list['channel_id']+'/about'
# title_list = []
# for url in url_list:
#     try:
#         r=requests.get(url)
#         soup=BeautifulSoup(r.text, "html.parser")
#         title=soup.find('meta', {'name':'title'}).attrs['content']

#         title_list.append(title)
#     except:
#         title_list.append('※크롤링 실패한 채널입니다!')
#     time.sleep(0.3)
    
# creator_list['channel_name']  = title_list
# creator_list = creator_list[['channel_name', 'name', 'account_id', 'channel_id']]
# # --------------------------------------------------------

# %%
cat2 = {'전체':'', '일상':12,'초스피드':18,'손님접대':13,'술안주':19,'다이어트':21,'도시락':15,'영양식':43,'간식':17,'야식':45,'푸드스타일링':20,
       '해장':46, '명절':44, '이유식':14, '기타':2}

# %%
r = requests.get('https://www.10000recipe.com/recipe/6850385')
soup=BeautifulSoup(r.content, "html.parser")
soup

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if (IE 6)|(IE 7)|(IE 8)|(IE 9)]>
# <html lang="ko" xmlns="http://www.w3.org/1999/xhtml" class="old_ie">
# <![endif]-->
# <?if !IE?>
# <html class="" lang="ko" xmlns="http://www.w3.org/1999/xhtml">
# <?endif?>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="-1" http-equiv="Expires"/>
# <meta content="1567451316868458" property="fb:pages"/>
# ...

# %%
soup.find(name='div')
# Out:
# <div class="gnb">
# <div class="gnb_top_wrap">
# <div class="gnb_top">
# <h1><a href="/index.html"><img alt="로고" src="https://recipe1.ezmember.co.kr/img/logo4.png"/></a></h1>
# <div class="gnb_search">
# <form action="/recipe/list.html" id="frmTopRecipeSearch" method="get">
# <div class="input-group">
# <input class="form-control" id="srhRecipeText" name="q" placeholder="" style="ime-mode:active;" type="text" value=""/>
# <span class="input-group-btn">
# <button class="btn btn-default" onclick="$('#frmTopRecipeSearch').submit();" type="button"><span class="glyphicon glyphicon-search"></span></button>
# </span>
# </div>
# </form>
# <div class="gnb_search_word">
# ...
